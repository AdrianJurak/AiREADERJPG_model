# %%
import os
import sys
sys.path.insert(0, os.path.abspath('.'))
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
 opt = get_config("config_files/en_filtered_config.yaml")
train(opt, amp=False)
# Out:
# --------------------------------------------------------------------------------
# dataset_root: /home/cipcius/PycharmProjects/AiREADERJPG/dataset
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    /home/cipcius/PycharmProjects/AiREADERJPG/dataset	 dataset: /
# /home/cipcius/PycharmProjects/AiREADERJPG/dataset/images
# sub-directory:	/images	 num samples: 1633
# /home/cipcius/PycharmProjects/AiREADERJPG/dataset/en_val/images
# sub-directory:	/en_val/images	 num samples: 412
# num total samples of /: 2045 x 1.0 (total_data_usage_ratio) = 2045
# num samples of / per batch: 7 x 1.0 (batch_ratio) = 7
# --------------------------------------------------------------------------------
# Total_batch_size: 7 = 7
# --------------------------------------------------------------------------------
# dataset_root:    /home/cipcius/PycharmProjects/AiREADERJPG/dataset/en_val	 dataset: /
# /home/cipcius/PycharmProjects/AiREADERJPG/dataset/en_val/images
# sub-directory:	/images	 num samples: 412
# --------------------------------------------------------------------------------
# model input parameters 100 1000 20 1 512 512 115 100 TPS VGG BiLSTM CTC
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# Model:
# DataParallel(
#   (module): Model(
#     (Transformation): TPS_SpatialTransformerNetwork(
#       (LocalizationNetwork): LocalizationNetwork(
#         (conv): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (10): ReLU(inplace=True)
#           (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (14): ReLU(inplace=True)
#           (15): AdaptiveAvgPool2d(output_size=1)
#         )
#         (localization_fc1): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (localization_fc2): Linear(in_features=256, out_features=40, bias=True)
#       )
#       (GridGenerator): GridGenerator()
#     )
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 512, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=1024, out_features=512, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(512, 512, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=1024, out_features=512, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=512, out_features=115, bias=True)
#   )
# )
# Modules, Parameters
# module.Transformation.LocalizationNetwork.conv.0.weight 576
# module.Transformation.LocalizationNetwork.conv.1.weight 64
# module.Transformation.LocalizationNetwork.conv.1.bias 64
# module.Transformation.LocalizationNetwork.conv.4.weight 73728
# module.Transformation.LocalizationNetwork.conv.5.weight 128
# module.Transformation.LocalizationNetwork.conv.5.bias 128
# module.Transformation.LocalizationNetwork.conv.8.weight 294912
# module.Transformation.LocalizationNetwork.conv.9.weight 256
# module.Transformation.LocalizationNetwork.conv.9.bias 256
# module.Transformation.LocalizationNetwork.conv.12.weight 1179648
# module.Transformation.LocalizationNetwork.conv.13.weight 512
# module.Transformation.LocalizationNetwork.conv.13.bias 512
# module.Transformation.LocalizationNetwork.localization_fc1.0.weight 131072
# module.Transformation.LocalizationNetwork.localization_fc1.0.bias 256
# module.Transformation.LocalizationNetwork.localization_fc2.weight 10240
# module.Transformation.LocalizationNetwork.localization_fc2.bias 40
# module.FeatureExtraction.ConvNet.0.weight 576
# module.FeatureExtraction.ConvNet.0.bias 64
# module.FeatureExtraction.ConvNet.3.weight 73728
# module.FeatureExtraction.ConvNet.3.bias 128
# module.FeatureExtraction.ConvNet.6.weight 294912
# module.FeatureExtraction.ConvNet.6.bias 256
# module.FeatureExtraction.ConvNet.8.weight 589824
# module.FeatureExtraction.ConvNet.8.bias 256
# module.FeatureExtraction.ConvNet.11.weight 1179648
# module.FeatureExtraction.ConvNet.12.weight 512
# module.FeatureExtraction.ConvNet.12.bias 512
# module.FeatureExtraction.ConvNet.14.weight 2359296
# module.FeatureExtraction.ConvNet.15.weight 512
# module.FeatureExtraction.ConvNet.15.bias 512
# module.FeatureExtraction.ConvNet.18.weight 1048576
# module.FeatureExtraction.ConvNet.18.bias 512
# module.SequenceModeling.0.rnn.weight_ih_l0 1048576
# module.SequenceModeling.0.rnn.weight_hh_l0 1048576
# module.SequenceModeling.0.rnn.bias_ih_l0 2048
# module.SequenceModeling.0.rnn.bias_hh_l0 2048
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 1048576
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 1048576
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 2048
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 2048
# module.SequenceModeling.0.linear.weight 524288
# module.SequenceModeling.0.linear.bias 512
# module.SequenceModeling.1.rnn.weight_ih_l0 1048576
# module.SequenceModeling.1.rnn.weight_hh_l0 1048576
# module.SequenceModeling.1.rnn.bias_ih_l0 2048
# module.SequenceModeling.1.rnn.bias_hh_l0 2048
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 1048576
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 1048576
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 2048
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 2048
# module.SequenceModeling.1.linear.weight 524288
# module.SequenceModeling.1.linear.bias 512
# module.Prediction.weight 58880
# module.Prediction.bias 115
# Total Trainable Params: 16755803
# Trainable params num :  16755803
# Optimizer:
# Adadelta (
# Parameter Group 0
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.1
#     maximize: False
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: 0123456789
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €
# lang_char: AĄBCĆDEĘFGHIJKLŁMŃNOÓPQRSŚTUVWXYZŻŹaąbcćdeęfghijklłmnńoópqrsśtuvwxyzżź
# experiment_name: en_filtered
# train_data: /home/cipcius/PycharmProjects/AiREADERJPG/dataset
# valid_data: /home/cipcius/PycharmProjects/AiREADERJPG/dataset/en_val
# manualSeed: 1111
# workers: 13
# batch_size: 7
# num_iter: 50000
# valInterval: 500
# saved_model:
# FT: False
# optim: False
# lr: 0.1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['/']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 100
# imgH: 100
# imgW: 1000
# rgb: False
# sensitive: True
# PAD: True
# contrast_adjust: 0.1
# data_filtering_off: True
# Transformation: TPS
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 512
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: 0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €AĄBCĆDEĘFGHIJKLŁMŃNOÓPQRSŚTUVWXYZŻŹaąbcćdeęfghijklłmnńoópqrsśtuvwxyzżź
# num_class: 115
# ---------------------------------------
#
# training time:  132.47732400894165
# [500/50000] Train loss: 4.43907, Valid loss: 3.63060, Elapsed_time: 132.47757
# Current_accuracy : 0.000, Current_norm_ED  : 0.0001
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0001
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# jedn.                     |                           | 0.0080	False
# Krok 2: Ustalamy typ: # zm. decyzyj: | "                         | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.201685667037964
# training time:  126.07095408439636
# [1000/50000] Train loss: 3.34455, Valid loss: 3.18195, Elapsed_time: 268.75042
# Current_accuracy : 0.000, Current_norm_ED  : 0.0830
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0830
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "KOLUMN, aby"             | P                         | 0.0000	False
# zamienimy zmienne         |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.393101930618286
# training time:  126.52959942817688
# [1500/50000] Train loss: 3.03943, Valid loss: 2.93630, Elapsed_time: 404.67336
# Current_accuracy : 0.000, Current_norm_ED  : 0.1083
# Best_accuracy    : 0.000, Best_norm_ED     : 0.1083
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Problem mieszania (diet)  |                           | 0.0000	False
# Zapiszemy je w konwencji macierzowej | Zy   y                    | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.462507009506226
# training time:  126.72090244293213
# [2000/50000] Train loss: 2.81193, Valid loss: 2.70954, Elapsed_time: 540.85698
# Current_accuracy : 0.000, Current_norm_ED  : 0.1625
# Best_accuracy    : 0.000, Best_norm_ED     : 0.1625
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ograniczony wielokątem    | yy k                      | 0.0000	False
# Rozwiązać PP oznacza      |  j                        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.583029985427856
# training time:  126.29714012145996
# [2500/50000] Train loss: 2.60096, Valid loss: 2.47401, Elapsed_time: 676.73736
# Current_accuracy : 0.243, Current_norm_ED  : 0.2505
# Best_accuracy    : 0.243, Best_norm_ED     : 0.2505
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Każde PPL                 | W P                       | 0.0000	False
# też pisali                | t pti                     | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.867103815078735
# training time:  127.02649092674255
# [3000/50000] Train loss: 2.33913, Valid loss: 2.22114, Elapsed_time: 813.63116
# Current_accuracy : 0.243, Current_norm_ED  : 0.3307
# Best_accuracy    : 0.243, Best_norm_ED     : 0.3307
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# w. wolny w. ogr.          | wwoy wog                  | 0.0000	False
# bo nie zmieniły           | ko e iniy                 | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.744593381881714
# training time:  128.72373485565186
# [3500/50000] Train loss: 2.14294, Valid loss: 2.35776, Elapsed_time: 952.09971
# Current_accuracy : 0.000, Current_norm_ED  : 0.3433
# Best_accuracy    : 0.243, Best_norm_ED     : 0.3433
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# zmiennych decyzyjnych:    | ziyd deyyd:               | 0.0000	False
# Przykład(z W1)            | Dy( W)                    | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.952294826507568
# training time:  127.34586906433105
# [4000/50000] Train loss: 1.93299, Valid loss: 2.07158, Elapsed_time: 1089.39808
# Current_accuracy : 1.942, Current_norm_ED  : 0.4657
# Best_accuracy    : 1.942, Best_norm_ED     : 0.4657
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# rezerwujemy miejsca odpowiadające tym | enajy ij odpoiadająie tymy | 0.0000	False
# "gdzie ""relatywne"       | gtre ełatye               | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.114955186843872
# training time:  126.68939900398254
# [4500/50000] Train loss: 1.78866, Valid loss: 1.68749, Elapsed_time: 1226.20265
# Current_accuracy : 1.456, Current_norm_ED  : 0.5126
# Best_accuracy    : 1.942, Best_norm_ED     : 0.5126
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# macierz współczynników    | maienm Moptpnik           | 0.0000	False
# Pokażmy jak powyższa analityczna postać zwija | Pokay jla poysy rltm posta zja | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.756974935531616
# training time:  127.36430978775024
# [5000/50000] Train loss: 1.66198, Valid loss: 1.51203, Elapsed_time: 1363.32415
# Current_accuracy : 3.883, Current_norm_ED  : 0.5881
# Best_accuracy    : 3.883, Best_norm_ED     : 0.5881
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Weźmy PPL typu            | Wey PPL tmpu              | 0.0000	False
# Wtedy efekt               | Wty ekkt                  | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.141546726226807
# training time:  127.05798721313477
# [5500/50000] Train loss: 1.51364, Valid loss: 1.38107, Elapsed_time: 1500.52389
# Current_accuracy : 6.068, Current_norm_ED  : 0.6377
# Best_accuracy    : 6.068, Best_norm_ED     : 0.6377
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Zwinąć PPL do postaci macierzowej. | Zinać Psoi do postai maii | 0.0000	False
# takim                     | tak                       | 0.0003	False
# --------------------------------------------------------------------------------
# validation time:  10.055946111679077
# training time:  126.5451455116272
# [6000/50000] Train loss: 1.41723, Valid loss: 1.32444, Elapsed_time: 1637.12518
# Current_accuracy : 6.068, Current_norm_ED  : 0.6427
# Best_accuracy    : 6.068, Best_norm_ED     : 0.6427
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# W tym celu zaczynamy od WIERSZY | W tym celu zazzymy od WELZC | 0.0000	False
# wartości f.celu           | yki felu                  | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.783906698226929
# training time:  126.45976257324219
# [6500/50000] Train loss: 1.33035, Valid loss: 1.24604, Elapsed_time: 1773.36906
# Current_accuracy : 6.553, Current_norm_ED  : 0.6813
# Best_accuracy    : 6.553, Best_norm_ED     : 0.6813
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# gdzie                     | gdze                      | 0.0097	False
# Słaba ZD von Neumanna     | taba ZD won Neumanna      | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.147332429885864
# training time:  126.02028799057007
# [7000/50000] Train loss: 1.25277, Valid loss: 1.10980, Elapsed_time: 1909.53689
# Current_accuracy : 8.981, Current_norm_ED  : 0.6966
# Best_accuracy    : 8.981, Best_norm_ED     : 0.6966
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# czyli                     | cyli                      | 0.0436	False
# Algorytm sprowadzenia     | Aygrytm sprowadzenia      | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.130735158920288
# training time:  126.16078448295593
# [7500/50000] Train loss: 1.18366, Valid loss: 1.11334, Elapsed_time: 2045.82863
# Current_accuracy : 10.922, Current_norm_ED  : 0.7209
# Best_accuracy    : 10.922, Best_norm_ED     : 0.7209
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# skonstruować              | skowstrwwj                | 0.0000	False
# 2) definicja              | ) dfinicjąi               | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.224504232406616
# training time:  126.12833642959595
# [8000/50000] Train loss: 1.12981, Valid loss: 1.01079, Elapsed_time: 2182.18166
# Current_accuracy : 13.107, Current_norm_ED  : 0.7376
# Best_accuracy    : 13.107, Best_norm_ED     : 0.7376
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Pokażmy jak powyższa analityczna postać zwija | Pokażmy jk poyżsy azaityna post zwaja | 0.0000	False
# zatem                     | atem                      | 0.0146	False
# --------------------------------------------------------------------------------
# validation time:  10.178855419158936
# training time:  126.3133897781372
# [8500/50000] Train loss: 1.09384, Valid loss: 1.04053, Elapsed_time: 2318.67414
# Current_accuracy : 10.922, Current_norm_ED  : 0.7255
# Best_accuracy    : 13.107, Best_norm_ED     : 0.7376
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# gdzie                     | gdzie                     | 0.1173	True
# geometryczny              | geoietzć                  | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.683463335037231
# training time:  125.9683141708374
# [9000/50000] Train loss: 1.00712, Valid loss: 0.90373, Elapsed_time: 2454.32612
# Current_accuracy : 14.078, Current_norm_ED  : 0.7586
# Best_accuracy    : 14.078, Best_norm_ED     : 0.7586
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# cena jedn. zakupu         | cena jedn. zakupu         | 0.0001	True
# Każde PPL                 | Każde PPL                 | 0.0136	True
# --------------------------------------------------------------------------------
# validation time:  10.032639503479004
# training time:  126.2202353477478
# [9500/50000] Train loss: 0.95041, Valid loss: 0.86839, Elapsed_time: 2590.57918
# Current_accuracy : 17.233, Current_norm_ED  : 0.7737
# Best_accuracy    : 17.233, Best_norm_ED     : 0.7737
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# PP typu min               | PP typu ii                | 0.0006	False
# ZAD                       | ZAD                       | 0.1668	True
# --------------------------------------------------------------------------------
# validation time:  10.207714080810547
# training time:  126.28217911720276
# [10000/50000] Train loss: 0.91510, Valid loss: 0.82395, Elapsed_time: 2727.06929
# Current_accuracy : 16.990, Current_norm_ED  : 0.7752
# Best_accuracy    : 17.233, Best_norm_ED     : 0.7752
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# jedn.                     | jedn.                     | 0.0305	True
# Max                       | Max                       | 0.1193	True
# --------------------------------------------------------------------------------
# validation time:  9.753218650817871
# training time:  125.77482867240906
# [10500/50000] Train loss: 0.88970, Valid loss: 0.74527, Elapsed_time: 2862.59753
# Current_accuracy : 21.845, Current_norm_ED  : 0.8182
# Best_accuracy    : 21.845, Best_norm_ED     : 0.8182
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# MIN oznacza               | Mj oznana,                | 0.0000	False
# MZD - mocna zasada dualności | MD - Moena zarada czylrośii | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.170876502990723
# training time:  126.21246266365051
# [11000/50000] Train loss: 0.81618, Valid loss: 0.76767, Elapsed_time: 2998.98108
# Current_accuracy : 17.961, Current_norm_ED  : 0.7833
# Best_accuracy    : 21.845, Best_norm_ED     : 0.8182
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# wartości                  | wrtoży                    | 0.0024	False
# PP sprowadzić do postaci standardowej | PP spowadzii do postai standucu | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.672559261322021
# training time:  126.35683536529541
# [11500/50000] Train loss: 0.78128, Valid loss: 0.61741, Elapsed_time: 3135.01067
# Current_accuracy : 24.757, Current_norm_ED  : 0.8386
# Best_accuracy    : 24.757, Best_norm_ED     : 0.8386
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Max                       | Max                       | 0.2278	True
# W4                        | W4                        | 0.7172	True
# --------------------------------------------------------------------------------
# validation time:  10.085625171661377
# training time:  125.87419319152832
# [12000/50000] Train loss: 0.74533, Valid loss: 0.91699, Elapsed_time: 3270.97069
# Current_accuracy : 14.563, Current_norm_ED  : 0.7497
# Best_accuracy    : 24.757, Best_norm_ED     : 0.8386
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# jest decyzją              | jest decyzją              | 0.0006	True
# dla DPPL                  | dla DgL                   | 0.0169	False
# --------------------------------------------------------------------------------
# validation time:  9.687706708908081
# training time:  126.19047689437866
# [12500/50000] Train loss: 0.70254, Valid loss: 0.58283, Elapsed_time: 3406.84908
# Current_accuracy : 26.942, Current_norm_ED  : 0.8480
# Best_accuracy    : 26.942, Best_norm_ED     : 0.8480
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Mamy sytuację             | Mamy ytację               | 0.0001	False
# wyznaczy dualne do niego  | wyznay dunalne do iego    | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.197694301605225
# training time:  126.18231558799744
# [13000/50000] Train loss: 0.67261, Valid loss: 0.52433, Elapsed_time: 3543.22929
# Current_accuracy : 30.825, Current_norm_ED  : 0.8758
# Best_accuracy    : 30.825, Best_norm_ED     : 0.8758
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# że takie P0 istnieje      | że take Po istnieje       | 0.0000	False
# o jakości mieszanki       | o jakości miezanti        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.218590259552002
# training time:  126.14852285385132
# [13500/50000] Train loss: 0.64611, Valid loss: 0.52060, Elapsed_time: 3679.59664
# Current_accuracy : 29.126, Current_norm_ED  : 0.8700
# Best_accuracy    : 30.825, Best_norm_ED     : 0.8758
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# z relacji                 | z relacji                 | 0.0482	True
# wszystkie komórki tego wiersza pomniejszając | wszystie komdzki tego wicrsnae pomniejsjąć | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.70326542854309
# training time:  125.7367033958435
# [14000/50000] Train loss: 0.62200, Valid loss: 0.49065, Elapsed_time: 3815.03681
# Current_accuracy : 31.068, Current_norm_ED  : 0.8715
# Best_accuracy    : 31.068, Best_norm_ED     : 0.8758
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Definiujemy macierze:     | Definiumy macierze:       | 0.0000	False
# "trzeba użyć pozostałych komórek, aby" | trzeba użyć pozostych komóokh, aby | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.937309741973877
# training time:  126.0491292476654
# [14500/50000] Train loss: 0.59257, Valid loss: 0.49607, Elapsed_time: 3951.02344
# Current_accuracy : 30.097, Current_norm_ED  : 0.8739
# Best_accuracy    : 31.068, Best_norm_ED     : 0.8758
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# W praktyce będzie to miejsce składowania nadwyżki | W prakke bydh to miejsne składowa nadwyżsi" | 0.0000	False
# ZAD. NAPISAĆ dla Min      | ZAD.NAMISAY dla Mi        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.76113224029541
# training time:  126.03810286521912
# [15000/50000] Train loss: 0.56994, Valid loss: 0.46321, Elapsed_time: 4086.82288
# Current_accuracy : 32.524, Current_norm_ED  : 0.8810
# Best_accuracy    : 32.524, Best_norm_ED     : 0.8810
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Oceń                      | Oceń                      | 0.0595	True
# czyli dualne do dualnego daje pierwotne. | czyli dualne do dualnego daje pierotne | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.010117769241333
# training time:  125.79836368560791
# [15500/50000] Train loss: 0.52374, Valid loss: 0.40587, Elapsed_time: 4222.63155
# Current_accuracy : 35.922, Current_norm_ED  : 0.8876
# Best_accuracy    : 35.922, Best_norm_ED     : 0.8876
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Najpierw ustalamy właściwe nierówności | Napiew staimy wtaśwe ieównoó | 0.0000	False
# "Proces ""domykania"" OZT do ZZT polega" | Proeć "donykama OZT do ZZT polega | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.029862403869629
# training time:  126.21866250038147
# [16000/50000] Train loss: 0.49834, Valid loss: 0.37565, Elapsed_time: 4358.88028
# Current_accuracy : 40.291, Current_norm_ED  : 0.9068
# Best_accuracy    : 40.291, Best_norm_ED     : 0.9068
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# macierz współczynników    | macierz współczynników    | 0.0005	True
# "jedno ""0"". Wskazuje ono komórkę" | jednio ,"o!. Wskazje ono kouóiśj | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.095589399337769
# training time:  125.9528706073761
# [16500/50000] Train loss: 0.47304, Valid loss: 0.36217, Elapsed_time: 4494.92894
# Current_accuracy : 39.078, Current_norm_ED  : 0.9014
# Best_accuracy    : 40.291, Best_norm_ED     : 0.9068
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# którą można               | którą można               | 0.0112	True
# p. analityczna            | I. analitya               | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.663933277130127
# training time:  126.02778387069702
# [17000/50000] Train loss: 0.45217, Valid loss: 0.34328, Elapsed_time: 4630.62088
# Current_accuracy : 35.437, Current_norm_ED  : 0.8974
# Best_accuracy    : 40.291, Best_norm_ED     : 0.9068
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# że takie P0 istnieje      | że take P istnieje        | 0.0003	False
# n - liczba argumentów funkcji celu | n -liczba argumntw fnkcji celu | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.674225807189941
# training time:  125.72647428512573
# [17500/50000] Train loss: 0.42347, Valid loss: 0.31936, Elapsed_time: 4766.02177
# Current_accuracy : 44.175, Current_norm_ED  : 0.9225
# Best_accuracy    : 44.175, Best_norm_ED     : 0.9225
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# że takie P0 istnieje      | że takie Po istnieje      | 0.0004	False
# (PPL) - problem programowania liniowego. | PPL)- problei programowanio liniowwngo" | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  10.089786767959595
# training time:  126.14240145683289
# [18000/50000] Train loss: 0.41323, Valid loss: 0.30603, Elapsed_time: 4902.25415
# Current_accuracy : 41.748, Current_norm_ED  : 0.9220
# Best_accuracy    : 44.175, Best_norm_ED     : 0.9225
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# wierszu wskazany limit    | wierszu wskazny liit      | 0.0001	False
# von Neumann               | von Nermann               | 0.0038	False
# --------------------------------------------------------------------------------
# validation time:  9.7057785987854
# training time:  126.19831871986389
# [18500/50000] Train loss: 0.39166, Valid loss: 0.27715, Elapsed_time: 5038.15845
# Current_accuracy : 46.845, Current_norm_ED  : 0.9278
# Best_accuracy    : 46.845, Best_norm_ED     : 0.9278
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Co to oznacza:            | (Co to oznacza:           | 0.0127	False
# zm. decyzyjne             | zrm. decyzyjne            | 0.0016	False
# --------------------------------------------------------------------------------
# validation time:  10.055402040481567
# training time:  125.80649638175964
# [19000/50000] Train loss: 0.36090, Valid loss: 0.25604, Elapsed_time: 5174.02055
# Current_accuracy : 49.029, Current_norm_ED  : 0.9313
# Best_accuracy    : 49.029, Best_norm_ED     : 0.9313
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Po tych zmianach, mamy ""nową"" zmienną" | Po tych zmianach, mamy "nową zmienną | 0.0000	False
# "zrealizować, bowiem"     | "zealizowaa, bowiem       | 0.0005	False
# --------------------------------------------------------------------------------
# validation time:  10.247021675109863
# training time:  126.15263342857361
# [19500/50000] Train loss: 0.34175, Valid loss: 0.22896, Elapsed_time: 5310.42040
# Current_accuracy : 56.068, Current_norm_ED  : 0.9448
# Best_accuracy    : 56.068, Best_norm_ED     : 0.9448
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "W tym przypadku wygodna, bo następują" | W tym przpadku wygda to nastopuja | 0.0000	False
# układ                     | układ                     | 0.4238	True
# --------------------------------------------------------------------------------
# validation time:  10.15662169456482
# training time:  126.13003158569336
# [20000/50000] Train loss: 0.31892, Valid loss: 0.24126, Elapsed_time: 5446.70726
# Current_accuracy : 47.330, Current_norm_ED  : 0.9349
# Best_accuracy    : 56.068, Best_norm_ED     : 0.9448
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Krok2. W każdym           | Krok2. W każdym           | 0.0025	True
# Podać p.analityczną       | Podać p.analityczy        | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  9.751845121383667
# training time:  125.89017224311829
# [20500/50000] Train loss: 0.31041, Valid loss: 0.24253, Elapsed_time: 5582.34949
# Current_accuracy : 48.786, Current_norm_ED  : 0.9314
# Best_accuracy    : 56.068, Best_norm_ED     : 0.9448
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4) definicja dziedziny f. celu | 4) defnizeja dziedzny f. celu | 0.0000	False
# PP sprowadzić do postaci standardowej | PP sprowadzi do postaci standondoej | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.656244993209839
# training time:  126.15460348129272
# [21000/50000] Train loss: 0.29383, Valid loss: 0.21063, Elapsed_time: 5718.16053
# Current_accuracy : 52.184, Current_norm_ED  : 0.9429
# Best_accuracy    : 56.068, Best_norm_ED     : 0.9448
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# nadwyżka                  | nadwyżka                  | 0.0845	True
# gdy PPPL                  | gdy PPPL                  | 0.1992	True
# --------------------------------------------------------------------------------
# validation time:  9.70415997505188
# training time:  126.15189957618713
# [21500/50000] Train loss: 0.27937, Valid loss: 0.17989, Elapsed_time: 5854.01680
# Current_accuracy : 59.951, Current_norm_ED  : 0.9576
# Best_accuracy    : 59.951, Best_norm_ED     : 0.9576
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Uwaga                     | Uwaga                     | 0.1552	True
# Rozw.                     | Rozw.                     | 0.1650	True
# --------------------------------------------------------------------------------
# validation time:  10.294727325439453
# training time:  126.05073714256287
# [22000/50000] Train loss: 0.26188, Valid loss: 0.23468, Elapsed_time: 5990.36248
# Current_accuracy : 50.971, Current_norm_ED  : 0.9380
# Best_accuracy    : 59.951, Best_norm_ED     : 0.9576
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Dalej będą rozważane tylko dwie następujące | Dalej będo rozważale tyllo die astęujce | 0.0000	False
# von Neumanna.             | von Neumanna.             | 0.0467	True
# --------------------------------------------------------------------------------
# validation time:  9.764215469360352
# training time:  125.78868389129639
# [22500/50000] Train loss: 0.25042, Valid loss: 0.17048, Elapsed_time: 6125.91558
# Current_accuracy : 59.466, Current_norm_ED  : 0.9585
# Best_accuracy    : 59.951, Best_norm_ED     : 0.9585
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# dla                       | dla                       | 0.2757	True
# ZAD2                      | ZAD2                      | 0.3571	True
# --------------------------------------------------------------------------------
# validation time:  9.96461796760559
# training time:  125.98584866523743
# [23000/50000] Train loss: 0.24165, Valid loss: 0.14852, Elapsed_time: 6261.86625
# Current_accuracy : 61.893, Current_norm_ED  : 0.9624
# Best_accuracy    : 61.893, Best_norm_ED     : 0.9624
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Wtedy oznaczamy           | Wtedy oznaczmy            | 0.0003	False
# ZAD. NAPISAĆ dla Min      | ZAD. NAPISAć dla Minm     | 0.0005	False
# --------------------------------------------------------------------------------
# validation time:  10.105608940124512
# training time:  125.98050928115845
# [23500/50000] Train loss: 0.23137, Valid loss: 0.17775, Elapsed_time: 6397.95259
# Current_accuracy : 59.951, Current_norm_ED  : 0.9542
# Best_accuracy    : 61.893, Best_norm_ED     : 0.9624
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# należy to zilustrować     | naebty to zilustrnować    | 0.0001	False
# zbiór rozw. dopuszczalnych | zbiór rozw. dopuczczanych | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.864419221878052
# training time:  125.9961040019989
# [24000/50000] Train loss: 0.22495, Valid loss: 0.15754, Elapsed_time: 6533.81332
# Current_accuracy : 58.010, Current_norm_ED  : 0.9583
# Best_accuracy    : 61.893, Best_norm_ED     : 0.9624
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# następująco:              | następująco               | 0.0007	False
# taki punkt                | taki punkt                | 0.1022	True
# --------------------------------------------------------------------------------
# validation time:  9.782947540283203
# training time:  126.18609237670898
# [24500/50000] Train loss: 0.20641, Valid loss: 0.14682, Elapsed_time: 6669.78258
# Current_accuracy : 65.049, Current_norm_ED  : 0.9661
# Best_accuracy    : 65.049, Best_norm_ED     : 0.9661
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# zatem                     | zatem                     | 0.3605	True
# "MAX oznacza, że"         | "MAX oznacza, że"         | 0.0031	True
# --------------------------------------------------------------------------------
# validation time:  10.111140489578247
# training time:  126.26241993904114
# [25000/50000] Train loss: 0.18807, Valid loss: 0.21402, Elapsed_time: 6806.15634
# Current_accuracy : 44.903, Current_norm_ED  : 0.9316
# Best_accuracy    : 65.049, Best_norm_ED     : 0.9661
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# warunków ograniczających  | warunków ogramiczająych   | 0.0000	False
# z relacji                 | z relacji                 | 0.0183	True
# --------------------------------------------------------------------------------
# validation time:  9.723891258239746
# training time:  126.05470204353333
# [25500/50000] Train loss: 0.19015, Valid loss: 0.14745, Elapsed_time: 6941.93515
# Current_accuracy : 57.282, Current_norm_ED  : 0.9590
# Best_accuracy    : 65.049, Best_norm_ED     : 0.9661
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ZAD. NAPISAĆ dla Min      | ZAD. NAPISAC dla Min      | 0.0043	False
# "Podany jest opis ilościowy PP, czyli model matematyczny" | "Podany ten opis ilośioy PP, cyligmodel matematyczny | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  9.768523931503296
# training time:  125.85785484313965
# [26000/50000] Train loss: 0.16351, Valid loss: 0.10512, Elapsed_time: 7077.56173
# Current_accuracy : 68.447, Current_norm_ED  : 0.9746
# Best_accuracy    : 68.447, Best_norm_ED     : 0.9746
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# składowym                 | składowym                 | 0.0874	True
# Pokażmy jak to się        | Pokażmy jak to się        | 0.0066	True
# --------------------------------------------------------------------------------
# validation time:  10.156501054763794
# training time:  126.23600459098816
# [26500/50000] Train loss: 0.16153, Valid loss: 0.10842, Elapsed_time: 7213.95444
# Current_accuracy : 66.990, Current_norm_ED  : 0.9713
# Best_accuracy    : 68.447, Best_norm_ED     : 0.9746
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# wszystkie komórki tego wiersza pomniejszając | wszystie komórki tego wiersza pomniejszająćc" | 0.0000	False
# Rozwiązać PP oznacza      | Rozwiąza PP oznacza       | 0.0551	False
# --------------------------------------------------------------------------------
# validation time:  9.80144214630127
# training time:  126.15683102607727
# [27000/50000] Train loss: 0.15733, Valid loss: 0.10943, Elapsed_time: 7349.91292
# ...
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# coś więcej                | coś więcej                | 0.0935	True
# np. z kryterium MAX(dla   | np z kryterium MAX(dla    | 0.0376	False
# --------------------------------------------------------------------------------
# validation time:  9.783921003341675
# training time:  125.75605201721191
# [40000/50000] Train loss: 0.04643, Valid loss: 0.03726, Elapsed_time: 10877.91577
# Current_accuracy : 82.039, Current_norm_ED  : 0.9907
# Best_accuracy    : 85.922, Best_norm_ED     : 0.9921
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# programowe dualne         | programowe dualne         | 0.0411	True
# ograniczony wielokątem    | ograniczony wielokątem    | 0.0027	True
# --------------------------------------------------------------------------------
# validation time:  9.798992395401001
# training time:  125.66954708099365
# [40500/50000] Train loss: 0.04588, Valid loss: 0.02416, Elapsed_time: 11013.38450
# Current_accuracy : 87.379, Current_norm_ED  : 0.9942
# Best_accuracy    : 87.379, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Tryb: on-line             | Tryb: on-line             | 0.0429	True
# Niech dane będą (PP) typu | Niech dane będą (PP) typu | 0.0255	True
# --------------------------------------------------------------------------------
# validation time:  10.307189464569092
# training time:  125.40564131736755
# [41000/50000] Train loss: 0.04484, Valid loss: 0.02409, Elapsed_time: 11149.09753
# Current_accuracy : 86.408, Current_norm_ED  : 0.9938
# Best_accuracy    : 87.379, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Zatem                     | Zatem                     | 0.3175	True
# ZAD                       | ZAD                       | 0.2887	True
# --------------------------------------------------------------------------------
# validation time:  9.789912700653076
# training time:  125.67216992378235
# [41500/50000] Train loss: 0.04306, Valid loss: 0.03553, Elapsed_time: 11284.55982
# Current_accuracy : 81.068, Current_norm_ED  : 0.9889
# Best_accuracy    : 87.379, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Jeśli                     | Jeśli                     | 0.2304	True
# "daną, u nas"             | "daną, u na"              | 0.1500	False
# --------------------------------------------------------------------------------
# validation time:  9.79233694076538
# training time:  125.55812191963196
# [42000/50000] Train loss: 0.04210, Valid loss: 0.02794, Elapsed_time: 11419.91047
# Current_accuracy : 85.680, Current_norm_ED  : 0.9924
# Best_accuracy    : 87.379, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Oceń                      | Oceń                      | 0.7760	True
# robi                      | robi                      | 0.5755	True
# --------------------------------------------------------------------------------
# validation time:  9.77422285079956
# training time:  125.64539051055908
# [42500/50000] Train loss: 0.03945, Valid loss: 0.04905, Elapsed_time: 11555.33030
# Current_accuracy : 77.913, Current_norm_ED  : 0.9860
# Best_accuracy    : 87.379, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# NB                        | NB                        | 0.5165	True
# wierszu wskazany limit    | wierszu wskazanmy limit   | 0.0096	False
# --------------------------------------------------------------------------------
# validation time:  9.732665538787842
# training time:  125.633385181427
# [43000/50000] Train loss: 0.03893, Valid loss: 0.02517, Elapsed_time: 11690.69654
# Current_accuracy : 85.922, Current_norm_ED  : 0.9934
# Best_accuracy    : 87.379, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# jest decyzją              | jest decyzją              | 0.1010	True
# Krok 2: Ustalamy typ: # zm. decyzyj: | Krok 2: Ustalamy typ: # zm. decyzyj: | 0.0006	True
# --------------------------------------------------------------------------------
# validation time:  9.799033880233765
# training time:  125.90785074234009
# [43500/50000] Train loss: 0.03784, Valid loss: 0.01940, Elapsed_time: 11826.40362
# Current_accuracy : 89.078, Current_norm_ED  : 0.9940
# Best_accuracy    : 89.078, Best_norm_ED     : 0.9942
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# składowana                | składowana                | 0.2729	True
# p. analityczna            | p. analityczna            | 0.0345	True
# --------------------------------------------------------------------------------
# validation time:  10.085826396942139
# training time:  125.78079986572266
# [44000/50000] Train loss: 0.03435, Valid loss: 0.02303, Elapsed_time: 11962.27044
# Current_accuracy : 89.806, Current_norm_ED  : 0.9958
# Best_accuracy    : 89.806, Best_norm_ED     : 0.9958
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Ten zdefiniuje PPL        | Ten zdefiniuje PPL        | 0.1666	True
# "MAX oznacza, że"         | "MAX oznacza, że"         | 0.0328	True
# --------------------------------------------------------------------------------
# validation time:  10.110878944396973
# training time:  125.39391112327576
# [44500/50000] Train loss: 0.03490, Valid loss: 0.01507, Elapsed_time: 12097.77543
# Current_accuracy : 92.718, Current_norm_ED  : 0.9968
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# (PPL)                     | (PPL)                     | 0.8024	True
# ZMIENNYCH w oryginalnym   | ZMIENNYCH w oryginalym    | 0.0037	False
# --------------------------------------------------------------------------------
# validation time:  10.369289875030518
# training time:  125.68679404258728
# [45000/50000] Train loss: 0.03111, Valid loss: 0.01555, Elapsed_time: 12233.83171
# Current_accuracy : 91.019, Current_norm_ED  : 0.9964
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Forma zajęć: Wykład       | Forma zajęć: Wykład       | 0.0545	True
# zużycie                   | zużycie                   | 0.6737	True
# --------------------------------------------------------------------------------
# validation time:  9.793942928314209
# training time:  125.78486227989197
# [45500/50000] Train loss: 0.03312, Valid loss: 0.02473, Elapsed_time: 12369.41071
# Current_accuracy : 86.408, Current_norm_ED  : 0.9933
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# dane liczby rzeczywiste   | dane liczby rzeczywiste   | 0.0453	True
# Na ogół zachowuje         | Na ogół zachowuje         | 0.1018	True
# --------------------------------------------------------------------------------
# validation time:  9.78055477142334
# training time:  125.50288987159729
# [46000/50000] Train loss: 0.03429, Valid loss: 0.02912, Elapsed_time: 12504.69435
# Current_accuracy : 85.194, Current_norm_ED  : 0.9922
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# zawartości składników     | zawartośi składników      | 0.0466	False
# Punktem wyjścia będzie PPL dane w postaci standardowej | Punktem wyjścia będzie PPL dane w postaci standardowej | 0.0000	True
# --------------------------------------------------------------------------------
# validation time:  9.713779211044312
# training time:  126.07566928863525
# [46500/50000] Train loss: 0.03019, Valid loss: 0.01994, Elapsed_time: 12640.48399
# Current_accuracy : 90.777, Current_norm_ED  : 0.9957
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# postaci DPPL:             | postaci DPPL:             | 0.1539	True
# dane liczby rzeczywiste   | dane liczby rzeczywiste   | 0.0400	True
# --------------------------------------------------------------------------------
# validation time:  9.7828528881073
# training time:  125.7583920955658
# [47000/50000] Train loss: 0.02747, Valid loss: 0.01631, Elapsed_time: 12776.02543
# Current_accuracy : 91.019, Current_norm_ED  : 0.9957
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Krok 1                    | Krok 1                    | 0.2655	True
# Oceń                      | Oceń                      | 0.3630	True
# --------------------------------------------------------------------------------
# validation time:  9.81310224533081
# training time:  125.94236135482788
# [47500/50000] Train loss: 0.03158, Valid loss: 0.01531, Elapsed_time: 12911.78108
# Current_accuracy : 91.262, Current_norm_ED  : 0.9965
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# oś rzeczywista            | oś rzeczywista            | 0.0507	True
# (dla MAX)                 | (dla MAX)                 | 0.2376	True
# --------------------------------------------------------------------------------
# validation time:  9.742316961288452
# training time:  125.5952639579773
# [48000/50000] Train loss: 0.02802, Valid loss: 0.01311, Elapsed_time: 13047.11885
# Current_accuracy : 91.990, Current_norm_ED  : 0.9968
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# "Jeśli PPPL zorientuje się na Min, to" | "Jeśli PPPL zrientuje się na Min, to | 0.0001	False
# Wtedy                     | Wtedy                     | 0.1972	True
# --------------------------------------------------------------------------------
# validation time:  9.766943216323853
# training time:  125.7154893875122
# [48500/50000] Train loss: 0.02737, Valid loss: 0.01143, Elapsed_time: 13182.60148
# Current_accuracy : 92.233, Current_norm_ED  : 0.9968
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# Metodologia modelowania zjawisk prowadzących do PPL | Metodologia modelowania zjawisk prowadzących do PPL | 0.0001	True
# MAX.                      | MAX.                      | 0.2779	True
# --------------------------------------------------------------------------------
# validation time:  9.811407804489136
# training time:  125.81348061561584
# [49000/50000] Train loss: 0.02588, Valid loss: 0.02278, Elapsed_time: 13318.22657
# Current_accuracy : 85.680, Current_norm_ED  : 0.9922
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# dla DPPL                  | dla DPPL                  | 0.6906	True
# dlatego                   | dlatego                   | 0.4159	True
# --------------------------------------------------------------------------------
# validation time:  9.771485805511475
# training time:  125.30557084083557
# [49500/50000] Train loss: 0.02447, Valid loss: 0.03000, Elapsed_time: 13453.30383
# Current_accuracy : 81.553, Current_norm_ED  : 0.9906
# Best_accuracy    : 92.718, Best_norm_ED     : 0.9968
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# do postaci analitycznej   | do postaci aualitycznej   | 0.0028	False
# "PPL dane jest w  postaci," | "PPL dane jest w postaci," | 0.0171	False
# --------------------------------------------------------------------------------
# validation time:  9.751095533370972
# training time:  125.74222421646118
# [50000/50000] Train loss: 0.02414, Valid loss: 0.01232, Elapsed_time: 13588.79736
# Current_accuracy : 94.175, Current_norm_ED  : 0.9975
# Best_accuracy    : 94.175, Best_norm_ED     : 0.9975
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# uzyskać                   | uzyskać                   | 0.3126	True
# nie jest sformułowane     | nie jest sformułowane     | 0.0154	True
# --------------------------------------------------------------------------------
# validation time:  10.165170192718506
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/cipcius/miniconda3/envs/AiREADERJPG/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
